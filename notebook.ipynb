# %% [markdown]
# # 1. De l'Inférence Populationnelle à la Prédiction Individuelle

# %% [markdown]
# - L'approche statistique "traditionnelle" vise l'inférence  populationnelle: on observe dans un échantillon et on généralise les conclusions à une population entière. On choisit la stratégie optimale pour le groupe mais pas forcément pour l'individu.
#
# ![Inférence stat.png](<attachment:Inférence stat.png>)
#
# - le machine learning se concentre sur la prédiction individuelle

# %%
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
file_path = "framingham.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "aasheesh200/framingham-heart-study-dataset",
  file_path)

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...
